# %%
import pandas as pd

# %%
st = pd.read_csv('/home/ifmt-aluno/Downloads/Cotação_do_dollar.csv')

# %%
st
# Out:
#          data   valor
# 0    01/01/26  5.5181
# 1    02/01/26    5.53
# 2    03/01/26    5.49
# 3    04/01/26    5.47
# 4    05/01/26    5.45
# ..        ...     ...
# 112  23/04/26  5.2136
# 113  24/04/26    5,00
# 114  25/04/26    5,00
# 115  26/04/26    5,00
# 116  27/04/26  5.0056
#
# [117 rows x 2 columns]

# %%
st.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117 entries, 0 to 116
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   data    117 non-null    object
#  1   valor   117 non-null    object
# dtypes: object(2)
# memory usage: 2.0+ KB

# %%
st['data'] = pd.to_datetime(st['data'], dayfirst=True)
# Out:
# /tmp/ipykernel_15234/1072971449.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   st['data'] = pd.to_datetime(st['data'], dayfirst=True)

# %%
st.set_index('data', inplace=True)

# %%
st.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 117 entries, 2026-01-01 to 2026-04-27
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   valor   117 non-null    object
# dtypes: object(1)
# memory usage: 1.8+ KB

# %%
st = st.asfreq('D')

# %%
st.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 117 entries, 2026-01-01 to 2026-04-27
# Freq: D
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   valor   117 non-null    object
# dtypes: object(1)
# memory usage: 1.8+ KB

# %%
st
# Out:
#              valor
# data
# 2026-01-01  5.5181
# 2026-01-02    5.53
# 2026-01-03    5.49
# 2026-01-04    5.47
# 2026-01-05    5.45
# ...            ...
# 2026-04-23  5.2136
# 2026-04-24    5,00
# 2026-04-25    5,00
# 2026-04-26    5,00
# 2026-04-27  5.0056
#
# [117 rows x 1 columns]

# %%
st.plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 st.plot()
#
# File ~/anaconda3/lib/python3.13/site-packages/pandas/plotting/_core.py:1030, in PlotAccessor.__call__(self, *args, **kwargs)
#    1027             label_name = label_kw or data.columns
#    1028             data.columns = label_name
# -> 1030 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~/anaconda3/lib/python3.13/site-packages/pandas/plotting/_matplotlib/__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File ~/anaconda3/lib/python3.13/site-packages/pandas/plotting/_matplotlib/core.py:499, in MPLPlot.generate(self)
#     497 @final
#     498 def generate(self) -> None:
# --> 499     self._compute_plot_data()
#     500     fig = self.fig
#     501     self._make_plot(fig)
#
# File ~/anaconda3/lib/python3.13/site-packages/pandas/plotting/_matplotlib/core.py:698, in MPLPlot._compute_plot_data(self)
#     696 # no non-numeric frames or series allowed
#     697 if is_empty:
# --> 698     raise TypeError("no numeric data to plot")
#     700 self.data = numeric_data.apply(type(self)._convert_to_ndarray)
#
# TypeError: no numeric data to plot

# %%
st.dropna(inplace=True)

# %%
st
# Out:
#              valor
# data
# 2026-01-01  5.5181
# 2026-01-02    5.53
# 2026-01-03    5.49
# 2026-01-04    5.47
# 2026-01-05    5.45
# ...            ...
# 2026-04-23  5.2136
# 2026-04-24    5,00
# 2026-04-25    5,00
# 2026-04-26    5,00
# 2026-04-27  5.0056
#
# [117 rows x 1 columns]

# %%
st.plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[76], line 1
# ----> 1 st.plot()
#
# File ~/anaconda3/lib/python3.13/site-packages/pandas/plotting/_core.py:1030, in PlotAccessor.__call__(self, *args, **kwargs)
#    1027             label_name = label_kw or data.columns
#    1028             data.columns = label_name
# -> 1030 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~/anaconda3/lib/python3.13/site-packages/pandas/plotting/_matplotlib/__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File ~/anaconda3/lib/python3.13/site-packages/pandas/plotting/_matplotlib/core.py:499, in MPLPlot.generate(self)
#     497 @final
#     498 def generate(self) -> None:
# --> 499     self._compute_plot_data()
#     500     fig = self.fig
#     501     self._make_plot(fig)
#
# File ~/anaconda3/lib/python3.13/site-packages/pandas/plotting/_matplotlib/core.py:698, in MPLPlot._compute_plot_data(self)
#     696 # no non-numeric frames or series allowed
#     697 if is_empty:
# --> 698     raise TypeError("no numeric data to plot")
#     700 self.data = numeric_data.apply(type(self)._convert_to_ndarray)
#
# TypeError: no numeric data to plot
